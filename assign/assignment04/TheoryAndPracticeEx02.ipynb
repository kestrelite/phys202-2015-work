# %% [markdown]
# # Theory and Practice of Visualization Exercise 2

# %% [markdown]
# ## Imports

# %%
from IPython.display import Image

# %% [markdown]
# ## Violations of graphical excellence and integrity

# %% [markdown]
# Find a data-focused visualization on one of the following websites that is a *negative* example of the principles that Tufte describes in *The Visual Display of Quantitative Information*.
#
# * [CNN](http://www.cnn.com/)
# * [Fox News](http://www.foxnews.com/)
# * [Time](http://time.com/)
#
# Upload the image for the visualization to this directory and display the image inline in this notebook.

# %%
Image(filename='Screenshot_144.png')

# %% [markdown]
# Describe in detail the ways in which the visualization violates graphical *integrity* and *excellence*:

# %% [markdown]
# Oh dear.
#
#  - First, the obvious thing. The text a) covers up most of the data on several graphs, and b) is the same color as the data, which means it's hard to tell which is which. Consequently, neither the text nor the graph is readable.
#  - The actual data is too fuzzy to make sense of. Despite the fact that it's been smoothed, fusion data is typically messy, but this is just absurd. It's important to be able to tell (particularly for this experiment) whether the data is trending up or down, and you honestly wouldn't know on a fine timescale.
#  - Why did they pick black font with a bright red border for that one message?
#  - The following names make absolutely no sense: gasa_cal, nebar_V2, HL89p, tauth, rvsout, bdotampl
#  - It's visually inconsistent. Why is the axis thick on one graph, but not the others? Why do the colors of the graphs not match up to the key describing what they are? Why does the red line not appear on one of the graphs?
#  - The scale is too small. Nobody would actually be able to tell you what the order of magnitudes on the numbers of these charts are, unless they happened to spend much time squinting at it.
#  - Second, the tick marks are either too wide or too thin vertically and horizontally. The minor ticks are useful, but unfortunately are about two pixels high and are useless. On one of the charts, the tick marks are too compact to be distinguishable.
#  - The line highlighting the critical moment of the reaction obscures what actually happens at that point. We don't know what that line means, either.
#
# (By the way, I actually had to pull data from this graph.)
